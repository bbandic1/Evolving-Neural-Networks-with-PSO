# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import sys

# Helper function to clean ATK/DEF
def clean_atk_def(value_text):
    """Cleans Attack/Defense values. Returns integer or None."""
    if value_text is None:
        return None
    cleaned_text = value_text.strip()
    if cleaned_text.isdigit():
        return int(cleaned_text)
    elif cleaned_text == '?' or cleaned_text == '-' or cleaned_text == '':
         return None # Represent unknown/non-applicable as None
    else:
        # Try to find digits anyway, sometimes there's extra text
        digits = re.findall(r'\d+', cleaned_text)
        if digits:
            return int(digits[0])
        return None # If truly non-numeric and not '?' or '-'

# Helper function to clean Type text
def clean_type_text(type_text):
    """Removes surrounding brackets and extra whitespace from Type."""
    if type_text is None:
        return None
    # Remove brackets and strip whitespace
    cleaned = type_text.replace('[', '').replace(']', '').strip()
    cleaned = re.sub(r'\s+/\s+', '/', cleaned)
    cleaned = re.sub(r'\s+', ' ', cleaned)
    return cleaned

# Configuration
BASE_URL_STRUCTURE = "https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd="
TOTAL_PAGES = 85
all_card_data = []
REQUEST_DELAY = 0.5

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

print("Starting scraping process...")

# --- Main Scraping Loop ---
try:
    for page_num in range(1, TOTAL_PAGES + 1):
        page_url = f"{BASE_URL_STRUCTURE}&page={page_num}"
        if "mode=" not in page_url:
             page_url += "&mode=1"
        elif "mode=&" in page_url:
             page_url = page_url.replace("mode=&", "mode=1&")


        print(f"\n--- Processing Page {page_num}/{TOTAL_PAGES} ---")
        print(f"URL: {page_url}")
        sys.stdout.flush()

        try:
            response = requests.get(page_url, headers=headers, timeout=20)
            response.raise_for_status()

        except requests.exceptions.RequestException as e:
            print(f"Error fetching page {page_num}: {e}. Skipping page.")
            time.sleep(REQUEST_DELAY)
            continue

        soup = BeautifulSoup(response.text, "html.parser")

        cards = soup.select("#card_list .t_row:not(.t_header)")

        if not cards:
            print(f"Warning: No cards found on page {page_num} using selector '#card_list .t_row'. Check if page structure changed or end of results.")
            card_list_div = soup.select_one("#card_list")
            if not card_list_div:
                print("Error: '#card_list' container not found either.")
            # If it's page 1 and no cards, something is wrong with the URL/selectors
            if page_num == 1:
                print("Error: No cards found on the first page. Please double-check BASE_URL_STRUCTURE and selectors.")
                break # Stop if the first page is empty
            time.sleep(REQUEST_DELAY)
            continue # Try the next page otherwise

        print(f"Found {len(cards)} card entries on page {page_num}.")

        # Loop through each card found on the page
        for card in cards:
            card_data = {}

            # Extract data using the selectors
            name_tag = card.select_one(".card_name")
            attr_tag = card.select_one(".box_card_attribute span")
            level_tag = card.select_one(".box_card_level_rank span")
            atk_tag = card.select_one(".atk_power span")
            def_tag = card.select_one(".def_power span")
            desc_tag = card.select_one(".box_card_text")

            type_tag = card.select_one(".card_info_species_and_other_item")

            # Populate the dictionary
            card_data['Name'] = name_tag.text.strip() if name_tag else None
            card_data['Attribute'] = attr_tag.text.strip() if attr_tag else None

            # Level/Rank
            level_text = level_tag.text.strip() if level_tag else None
            if level_text and level_text.isdigit():
                 card_data['Level'] = int(level_text)
            else:
                 card_data['Level'] = level_text

            # ATK/DEF
            card_data['ATK'] = clean_atk_def(atk_tag.text) if atk_tag else None
            card_data['DEF'] = clean_atk_def(def_tag.text) if def_tag else None

            # Description
            card_data['Description'] = desc_tag.text.strip() if desc_tag else None

            # Type (Cleaned)
            card_data['Type'] = clean_type_text(type_tag.text) if type_tag else None

            # Add the extracted data to our main list
            if card_data['Name']:
                 all_card_data.append(card_data)

        time.sleep(REQUEST_DELAY)

except KeyboardInterrupt:
    print("\nScraping interrupted by user.")

finally:
    # Process Data
    print("\n--- Scraping Finished (or Interrupted) ---")

    if all_card_data:
        df = pd.DataFrame(all_card_data)

        cols_order = ['Name', 'Attribute', 'Level', 'Type', 'ATK', 'DEF', 'Description']
        for col in cols_order:
            if col not in df.columns:
                df[col] = None
        df = df[cols_order]


        print(f"\nSuccessfully scraped {len(df)} cards.")
        print("DataFrame Info:")
        df.info()
        print("\nDataFrame Head (showing Type column):")
        print(df.head())
        print("\nCheck a few rows for Type data:")
        print(df[['Name', 'Type']].head(10))


        # Save to CSV
        csv_path_local = 'yugioh_monster_cards.csv'
        try:
            df.to_csv(csv_path_local, index=False)
            print(f"\nDataFrame saved locally to {csv_path_local}")
            print("You can download this file from the Colab file browser (folder icon on the left).")
        except Exception as e:
            print(f"Error saving DataFrame to CSV: {e}")

    else:
        print("No card data was scraped.")
# Out:
# Starting scraping process...
#
# --- Processing Page 1/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=1
# Found 100 card entries on page 1.
#
# --- Processing Page 2/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=2
# Found 100 card entries on page 2.
#
# --- Processing Page 3/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=3
# Found 100 card entries on page 3.
#
# --- Processing Page 4/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=4
# Found 100 card entries on page 4.
#
# --- Processing Page 5/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=5
# Found 100 card entries on page 5.
#
# --- Processing Page 6/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=6
# Found 100 card entries on page 6.
#
# --- Processing Page 7/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=7
# Found 100 card entries on page 7.
#
# --- Processing Page 8/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=8
# Found 100 card entries on page 8.
#
# --- Processing Page 9/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=9
# Found 100 card entries on page 9.
#
# --- Processing Page 10/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=10
# Found 100 card entries on page 10.
#
# --- Processing Page 11/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=11
# Found 100 card entries on page 11.
#
# --- Processing Page 12/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=12
# Found 100 card entries on page 12.
#
# --- Processing Page 13/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=13
# Found 100 card entries on page 13.
#
# --- Processing Page 14/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=14
# Found 100 card entries on page 14.
#
# --- Processing Page 15/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=15
# Found 100 card entries on page 15.
#
# --- Processing Page 16/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=16
# Found 100 card entries on page 16.
#
# --- Processing Page 17/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=17
# Found 100 card entries on page 17.
#
# --- Processing Page 18/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=18
# Found 100 card entries on page 18.
#
# --- Processing Page 19/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=19
# Found 100 card entries on page 19.
#
# --- Processing Page 20/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=20
# Found 100 card entries on page 20.
#
# --- Processing Page 21/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=21
# Found 100 card entries on page 21.
#
# --- Processing Page 22/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=22
# Found 100 card entries on page 22.
#
# --- Processing Page 23/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=23
# Found 100 card entries on page 23.
#
# --- Processing Page 24/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=24
# Found 100 card entries on page 24.
#
# --- Processing Page 25/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=25
# Found 100 card entries on page 25.
#
# --- Processing Page 26/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=26
# Found 100 card entries on page 26.
#
# --- Processing Page 27/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=27
# Found 100 card entries on page 27.
#
# --- Processing Page 28/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=28
# Found 100 card entries on page 28.
#
# --- Processing Page 29/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=29
# Found 100 card entries on page 29.
#
# --- Processing Page 30/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=30
# Found 100 card entries on page 30.
#
# --- Processing Page 31/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=31
# Found 100 card entries on page 31.
#
# --- Processing Page 32/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=32
# Found 100 card entries on page 32.
#
# --- Processing Page 33/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=33
# Found 100 card entries on page 33.
#
# --- Processing Page 34/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=34
# Found 100 card entries on page 34.
#
# --- Processing Page 35/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=35
# Found 100 card entries on page 35.
#
# --- Processing Page 36/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=36
# Found 100 card entries on page 36.
#
# --- Processing Page 37/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=37
# Found 100 card entries on page 37.
#
# --- Processing Page 38/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=38
# Found 100 card entries on page 38.
#
# --- Processing Page 39/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=39
# Found 100 card entries on page 39.
#
# --- Processing Page 40/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=40
# Found 100 card entries on page 40.
#
# --- Processing Page 41/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=41
# Found 100 card entries on page 41.
#
# --- Processing Page 42/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=42
# Found 100 card entries on page 42.
#
# --- Processing Page 43/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=43
# Found 100 card entries on page 43.
#
# --- Processing Page 44/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=44
# Found 100 card entries on page 44.
#
# --- Processing Page 45/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=45
# Found 100 card entries on page 45.
#
# --- Processing Page 46/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=46
# Found 100 card entries on page 46.
#
# --- Processing Page 47/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=47
# Found 100 card entries on page 47.
#
# --- Processing Page 48/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=48
# Found 100 card entries on page 48.
#
# --- Processing Page 49/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=49
# Found 100 card entries on page 49.
#
# --- Processing Page 50/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=50
# Found 100 card entries on page 50.
#
# --- Processing Page 51/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=51
# Found 100 card entries on page 51.
#
# --- Processing Page 52/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=52
# Found 100 card entries on page 52.
#
# --- Processing Page 53/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=53
# Found 100 card entries on page 53.
#
# --- Processing Page 54/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=54
# Found 100 card entries on page 54.
#
# --- Processing Page 55/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=55
# Found 100 card entries on page 55.
#
# --- Processing Page 56/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=56
# Found 100 card entries on page 56.
#
# --- Processing Page 57/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=57
# Found 100 card entries on page 57.
#
# --- Processing Page 58/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=58
# Found 100 card entries on page 58.
#
# --- Processing Page 59/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=59
# Found 100 card entries on page 59.
#
# --- Processing Page 60/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=60
# Found 100 card entries on page 60.
#
# --- Processing Page 61/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=61
# Found 100 card entries on page 61.
#
# --- Processing Page 62/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=62
# Found 100 card entries on page 62.
#
# --- Processing Page 63/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=63
# Found 100 card entries on page 63.
#
# --- Processing Page 64/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=64
# Found 100 card entries on page 64.
#
# --- Processing Page 65/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=65
# Found 100 card entries on page 65.
#
# --- Processing Page 66/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=66
# Found 100 card entries on page 66.
#
# --- Processing Page 67/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=67
# Found 100 card entries on page 67.
#
# --- Processing Page 68/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=68
# Found 100 card entries on page 68.
#
# --- Processing Page 69/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=69
# Found 100 card entries on page 69.
#
# --- Processing Page 70/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=70
# Found 100 card entries on page 70.
#
# --- Processing Page 71/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=71
# Found 100 card entries on page 71.
#
# --- Processing Page 72/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=72
# Found 100 card entries on page 72.
#
# --- Processing Page 73/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=73
# Found 100 card entries on page 73.
#
# --- Processing Page 74/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=74
# Found 100 card entries on page 74.
#
# --- Processing Page 75/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=75
# Found 100 card entries on page 75.
#
# --- Processing Page 76/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=76
# Found 100 card entries on page 76.
#
# --- Processing Page 77/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=77
# Found 100 card entries on page 77.
#
# --- Processing Page 78/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=78
# Found 100 card entries on page 78.
#
# --- Processing Page 79/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=79
# Found 100 card entries on page 79.
#
# --- Processing Page 80/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=80
# Found 100 card entries on page 80.
#
# --- Processing Page 81/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=81
# Found 100 card entries on page 81.
#
# --- Processing Page 82/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=82
# Found 100 card entries on page 82.
#
# --- Processing Page 83/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=83
# Found 100 card entries on page 83.
#
# --- Processing Page 84/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=84
# Found 100 card entries on page 84.
#
# --- Processing Page 85/85 ---
# URL: https://www.db.yugioh-card.com/yugiohdb/card_search.action?ope=1&sess=1&rp=100&mode=1&sort=1&keyword=&stype=1&ctype=1&othercon=2&starfr=&starto=&pscalefr=&pscaleto=&linkmarkerfr=&linkmarkerto=&link_m=2&atkfr=&atkto=&deffr=&defto=&releaseDStart=1&releaseMStart=1&releaseYStart=1999&releaseDEnd=&releaseMEnd=&releaseYEnd=&page=85
# Found 67 card entries on page 85.
#
# --- Scraping Finished (or Interrupted) ---
#
# Successfully scraped 8467 cards.
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8467 entries, 0 to 8466
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8467 non-null   object
#  1   Attribute    8467 non-null   object
#  2   Level        8047 non-null   object
#  3   Type         8467 non-null   object
#  4   ATK          8387 non-null   float64
#  5   DEF          7994 non-null   float64
#  6   Description  8467 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 463.2+ KB
#
# DataFrame Head (showing Type column):
#                                Name Attribute    Level                Type  \
# 0                    3-Hump Lacooda     EARTH  Level 3        Beast/Effect
# 1         4-Starred Ladybug of Doom      WIND  Level 3  Insect/Flip／Effect
# 2                    7 Colored Fish     WATER  Level 4         Fish/Normal
# 3                  8-Claws Scorpion      DARK  Level 2       Insect/Effect
# 4  A Bao A Qu, the Lightless Shadow      DARK     None   Fiend/Link／Effect
#
#       ATK     DEF                                        Description
# 0   500.0  1500.0  If there are 3 face-up "3-Hump Lacooda" cards ...
# 1   800.0  1200.0  FLIP: Destroy all Level 4 monsters your oppone...
# 2  1800.0   800.0  A rare rainbow fish that has never been caught...
# 3   300.0   200.0  Once per turn, you can flip this card into fac...
# 4  2800.0     NaN  2+ monsters, including a Fiend monsterDuring t...
#
# Check a few rows for Type data:
#                                Name                   Type
# 0                    3-Hump Lacooda           Beast/Effect
# 1         4-Starred Ladybug of Doom     Insect/Flip／Effect
# 2                    7 Colored Fish            Fish/Normal
# 3                  8-Claws Scorpion          Insect/Effect
# 4  A Bao A Qu, the Lightless Shadow      Fiend/Link／Effect
# 5                 A Cat of Ill Omen      Beast/Flip／Effect
# 6                  A Man with Wdjat     Spellcaster/Effect
# 7                    A-Assault Core   Machine/Union／Effect
# 8        A-Team: Trap Disposal Unit         Machine/Effect
# 9       A-to-Z-Dragon Buster Cannon  Machine/Fusion／Effect
#
# DataFrame saved locally to yugioh_monster_cards.csv
# You can download this file from the Colab file browser (folder icon on the left).

# %%
import json
import math

# File Paths
csv_path_local = 'yugioh_monster_cards.csv'
json_path_local = 'yugioh_monster_cards.json'

print(f"Attempting to read CSV file: {csv_path_local}")

try:
    # Read CSV
    df = pd.read_csv(csv_path_local)
    print(f"Successfully read {len(df)} rows from {csv_path_local}")
    print("Original DataFrame info:")
    df.info()
    print("\nSample of original 'Type' column before cleaning:")
    if 'Type' in df.columns:
      problematic_types = df[df['Type'].astype(str).str.contains('／', na=False)]['Type'].head()
      if not problematic_types.empty:
          print(problematic_types)
      else:
          print("No types with '／' found in the sample head.")
    print("\nSample of original 'Level', 'ATK', 'DEF' columns:")
    print(df[['Name', 'Level', 'ATK', 'DEF']].head(10))

    # Fix 'Type' column
    if 'Type' in df.columns:
        print("\nCleaning the 'Type' column...")
        original_type_nan_mask = df['Type'].isna()
        df['Type'] = df['Type'].astype(str).str.replace('／', '/', regex=False)
        df.loc[df['Type'].str.lower() == 'nan', 'Type'] = None
        df.loc[original_type_nan_mask, 'Type'] = None
        print("Cleaning complete.")
    else:
        print("Warning: 'Type' column not found in the CSV. Skipping cleaning step.")

    # Process 'Level' column
    if 'Level' in df.columns:
        print("\nFilling missing 'Level' values with 0 and converting to int...")
        try:
             df['Level'] = pd.to_numeric(df['Level'], errors='coerce')
             df['Level'].fillna(0, inplace=True)
             df['Level'] = df['Level'].astype(int)
             print("Processing 'Level' complete.")
        except Exception as e:
             print(f"Could not process 'Level' column fully: {e}.")
    else:
        print("Warning: 'Level' column not found in the CSV.")

    # Process 'ATK' column
    if 'ATK' in df.columns:
        print("\nFilling missing 'ATK' values with 0 and converting to int...")
        try:
            df['ATK'] = pd.to_numeric(df['ATK'], errors='coerce')
            df['ATK'].fillna(0, inplace=True)
            df['ATK'] = df['ATK'].astype(int)
            print("Processing 'ATK' complete.")
        except Exception as e:
             print(f"Could not process 'ATK' column fully: {e}.")
    else:
        print("Warning: 'ATK' column not found in the CSV.")

    # Process 'DEF' column
    if 'DEF' in df.columns:
        print("\nFilling missing 'DEF' values with 0 and converting to int...")
        try:
            df['DEF'] = pd.to_numeric(df['DEF'], errors='coerce')
            df['DEF'].fillna(0, inplace=True)
            df['DEF'] = df['DEF'].astype(int)
            print("Processing 'DEF' complete.")
        except Exception as e:
             print(f"Could not process 'DEF' column fully: {e}.")
    else:
        print("Warning: 'DEF' column not found in the CSV.")

    print("\nDataFrame info after cleaning and filling:")
    df.info()
    print("\nSample data after cleaning/filling:")
    print(df[['Name', 'Level', 'ATK', 'DEF', 'Type']].head(10))

    # Convert DataFrame to JSON
    print(f"\nConverting DataFrame to JSON format (orient='records')...")
    data_list = df.to_dict(orient='records')

    # Clean up any remaining float NaNs before JSON dump
    for record in data_list:
        for key, value in record.items():
            if isinstance(value, float) and math.isnan(value):
                record[key] = None

    print(f"Saving cleaned data to JSON file: {json_path_local}")

    # Save to JSON file
    with open(json_path_local, 'w', encoding='utf-8') as f:
        json.dump(data_list, f, ensure_ascii=False, indent=4)

    print(f"\nSuccessfully saved cleaned data to {json_path_local}")
    print("You can find the JSON file in the Colab file browser.")


except FileNotFoundError:
    print(f"Error: The file '{csv_path_local}' was not found.")
    print("Please make sure the CSV file exists in the '/content/' directory in Colab.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Attempting to read CSV file: yugioh_monster_cards.csv
# Successfully read 8467 rows from yugioh_monster_cards.csv
# Original DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8467 entries, 0 to 8466
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8467 non-null   object
#  1   Attribute    8467 non-null   object
#  2   Level        8047 non-null   object
#  3   Type         8467 non-null   object
#  4   ATK          8387 non-null   float64
#  5   DEF          7994 non-null   float64
#  6   Description  8467 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 463.2+ KB
#
# Sample of original 'Type' column before cleaning:
# 1       Insect/Flip／Effect
# 4        Fiend/Link／Effect
# 5        Beast/Flip／Effect
# 7     Machine/Union／Effect
# 9    Machine/Fusion／Effect
# Name: Type, dtype: object
#
# Sample of original 'Level', 'ATK', 'DEF' columns:
#                                Name     Level     ATK     DEF
# 0                    3-Hump Lacooda   Level 3   500.0  1500.0
# 1         4-Starred Ladybug of Doom   Level 3   800.0  1200.0
# 2                    7 Colored Fish   Level 4  1800.0   800.0
# 3                  8-Claws Scorpion   Level 2   300.0   200.0
# 4  A Bao A Qu, the Lightless Shadow       NaN  2800.0     NaN
# 5                 A Cat of Ill Omen   Level 2   500.0   300.0
# 6                  A Man with Wdjat   Level 4  1600.0  1600.0
# 7                    A-Assault Core   Level 4  1900.0   200.0
# 8        A-Team: Trap Disposal Unit   Level 2   300.0   400.0
# 9       A-to-Z-Dragon Buster Cannon  Level 10  4000.0  4000.0
#
# Cleaning the 'Type' column...
# Cleaning complete.
#
# Filling missing 'Level' values with 0 and converting to int...
# Processing 'Level' complete.
#
# Filling missing 'ATK' values with 0 and converting to int...
# Processing 'ATK' complete.
#
# Filling missing 'DEF' values with 0 and converting to int...
# Processing 'DEF' complete.
#
# DataFrame info after cleaning and filling:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8467 entries, 0 to 8466
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8467 non-null   object
#  1   Attribute    8467 non-null   object
#  2   Level        8467 non-null   int64
#  3   Type         8467 non-null   object
#  4   ATK          8467 non-null   int64
#  5   DEF          8467 non-null   int64
#  6   Description  8467 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 463.2+ KB
#
# Sample data after cleaning/filling:
#                                Name  Level   ATK   DEF                   Type
# 0                    3-Hump Lacooda      0   500  1500           Beast/Effect
# 1         4-Starred Ladybug of Doom      0   800  1200     Insect/Flip/Effect
# 2                    7 Colored Fish      0  1800   800            Fish/Normal
# 3                  8-Claws Scorpion      0   300   200          Insect/Effect
# 4  A Bao A Qu, the Lightless Shadow      0  2800     0      Fiend/Link/Effect
# 5                 A Cat of Ill Omen      0   500   300      Beast/Flip/Effect
# 6                  A Man with Wdjat      0  1600  1600     Spellcaster/Effect
# 7                    A-Assault Core      0  1900   200   Machine/Union/Effect
# 8        A-Team: Trap Disposal Unit      0   300   400         Machine/Effect
# 9       A-to-Z-Dragon Buster Cannon      0  4000  4000  Machine/Fusion/Effect
#
# Converting DataFrame to JSON format (orient='records')...
# <ipython-input-21-0dc6726c130b>:42: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Level'].fillna(0, inplace=True)
# <ipython-input-21-0dc6726c130b>:55: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ATK'].fillna(0, inplace=True)
# <ipython-input-21-0dc6726c130b>:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DEF'].fillna(0, inplace=True)
# Saving cleaned data to JSON file: yugioh_monster_cards.json
#
# Successfully saved cleaned data to yugioh_monster_cards.json
# You can find the JSON file in the Colab file browser.
